# %% [markdown]
# ## 5.4 Tyre-kicking
#
# ### What we doing here?
#
# 'The modernisation of key services, especially of services for data currently underdeveloped in the DiSSCo community, is of great importance for the overall improvement of the technical readiness level from the DiSSCo RI.
#
# This task is focusing on construction plans for the improvement of technical infrastructure in the identified key areas of geo-collection data and taxonomic services. Geo-collection data are highly underrepresented in terms of available services for data mobilisation and publication. Thus, these services need special consideration in order to significantly increase DiSSCo technical readiness in the earth scientific domain. In addition, the harmonisation of life science taxonomic checklist services (e.g. Catalogue of Life) needs construction plans for the integration into DiSSCo architecture in order to exploit their full value as a taxonomic backbone.
#
# This task will focus on the investigation of existing tools and provide necessary plans for seamless integration into the overall DiSSCo technical architecture.'
#
# [WP 5.4 overview + planning notes](https://docs.google.com/spreadsheets/d/1W9OmZ9qD6GNjmOtTT58F94-u9jrsK_gAK8MK_fnSJVY/edit#gid=1897609990)
# [WP 5.4 meeting notes](https://docs.google.com/document/d/1oplZIkp4jQ6txwElMaU_u23D9SEQmxKoIeMFNqwyZNA/edit)
#
# #### Data stores of interest
# [Geocase](https://geocase.eu/)
# [Catalogue of Life](https://www.catalogueoflife.org/)
# [NSDIR](https://nsidr.org/#)
#
# #### Related packages:
# [WP 6.1 notes](https://docs.google.com/document/d/176jxNxE_MkPgXn70XCx5eKtKqGCBQYTvA8D9Lh_qyEk/edit#heading=h.1cc0x84qr23r)
# [WP 6.1 event-storming notes](https://miro.com/app/board/o9J_lVwIZ9Q=/)
#
# #### Background links:
# *Event sourcing*
# * https://eventuate.io/
# * https://www.eventstore.com/eventstoredb
# * https://microservices.io/patterns/data/event-sourcing.html
# * https://microservices.io/patterns/data/cqrs.html
# * https://docs.microsoft.com/en-us/azure/architecture/patterns/event-sourcing
# * https://www.confluent.co.uk/blog/event-sourcing-cqrs-stream-processing-apache-kafka-whats-connection/
#
# *Event stream processing*
# * https://en.wikipedia.org/wiki/Event_stream_processing
#
# ### What _you_ doing here, Sarah?
#
# Best if you don't think about that too deeply tbh. But, since you're asking, today's side-quest is to do a first-pass of a few different data services (listed above) to see what they have in terms of the following:
# 1. Documentation
# 2. API endpoints
# 3. Any sort of event-streaming functionality (versioning, cause-of-change data, ...?)
#
# ... so this definitely doesn't need to be in a notebook, but HEY you're here now so might as well. Don't get distracted, Sarah, just do the thing.

# %%
import requests
from collections import Counter

# %% [markdown]
# ___________
# ### 1. Geocase
# ____________
#
# 1.6m records at time of testing, from eight sources. Although it looks like they're pulling a bunch of the data from an older version of GeoCase? Something to ask about, ref this example [bio/geocase xml record](https://bc.geocollections.info/pywrapper.cgi?dsa=sarv) pulled from a `dataseturl` field
#
# [Web app](https://geocase.geocollections.info/)
#
#
# #### Documentation
#
# [API docs](https://api.geocase.eu/api-docs/) - Documented according to openapi, using Swagger. Brief, but their API uses default Solr syntax/operations so more detail can be found in the [Solr docs](https://lucene.apache.org/solr/guide/8_6/searching.html).
#
#
# #### Endpoints
#
# `/solr` is the main search endpoint. It 'returns specimens using default Apache Solr response' so you can do Fairly Snazzy Searches (ranges, exists/does not exist, etc)
#
# `/repeat` is mystifying. Looks like it queries the original service? From the docs, the input param is the original url from the source service, so I would've assumed you used it in conjunction with fields returned by `/solr` endpoint to stitch together a call to the other service.
#
# `/mock` returns dummy data - something used for dev/testing, I suppose?

# %%
gc_url_base = 'https://api.geocase.eu/v1'
gc_search = '/solr'

# query below brings back first 1k records that aren't from NHMUK, GIT or MfN
gc_params = {
    'q': '*', 
    'fq': 'datasetownerabbrev:(!UK-NHM !GIT !MfN)', # exclude results from these three institutes
    'rows': 1000
    }

# fl parameter limits the fields returned to just interesting ones - eg below
# 'fl': 'id,last_harvested_processing,datasetownerabbrev,datasourceurl,providerurl,occurrenceid,unitid',

gc_r = requests.get(gc_url_base + gc_search, params=gc_params)

# %%
gc_response = gc_r.json()
gc_records = gc_response['response']['docs']

# little peep at an example record
gc_records[:1]
# Out:
# [{'country_original': 'Estonia',
#   'country': 'Estonia',
#   'collectioncode': 'TAM',
#   'is_mineral': True,
#   'datasetownerabbrev': 'TAM',
#   'stratigraphies': ['Llandovery', 'Raikküla Stage'],
#   'last_harvested_processing': '2021-03-25T10:58:56Z',
#   'id': '756664',
#   'longitude': 25.743369,
#   'recordbasis': 'Rock',
#   'datasourcecountry': 'Estonia',
#   'locality': 'Koigi old quarry, Järvamaa',
#   'occurrenceid': 756664,
#   'provideraddress': 'Ehitajate tee 5, 12616 Tallinn',
#   'has_map': True,
#   'cetaf_identifier': 'ee-nhm',
#   'datasourceurl': 'https://bc.geocollections.info/pywrapper.cgi?dsa=sarv',
#   'datasetowner': 'Estonian Museum of Natural History',
#   'fullscientificname': 'sedimentary rocks',
#   'latitude': 58.850797,
#   'providercountry': 'Estonia',
#   'stratigraphy': 'Raikküla Stage',
#   'providerurl': 'https://geocollections.info/',
#   'has_image': False,
#   'recordURI': 'https://geocollections.info/specimen/189164',
#   'coordinates': '58.850797,25.743369',
#   'collectorname': 'Klaamann',
#   'providername': 'SARV',
#   'names': ['sedimentary rocks'],
#   'unitid': 'G121:7',
#   '_version_': 1713062973767942148}]

# %%
# use the first 1k records to get a list of record fields and data types, for funsies/so we don't miss any 
gc_fields = Counter([(k, type(v)) for x in gc_records for k, v in x.items()])

# generate a list of fields, data types and frequency in our sample
gc_fields.most_common()
# Out:
# [(('collectioncode', str), 1000),
#  (('datasetownerabbrev', str), 1000),
#  (('last_harvested_processing', str), 1000),
#  (('id', str), 1000),
#  (('recordbasis', str), 1000),
#  (('datasourcecountry', str), 1000),
#  (('occurrenceid', int), 1000),
#  (('provideraddress', str), 1000),
#  (('has_map', bool), 1000),
#  (('cetaf_identifier', str), 1000),
#  (('datasourceurl', str), 1000),
#  (('datasetowner', str), 1000),
#  (('providercountry', str), 1000),
#  (('providerurl', str), 1000),
#  (('has_image', bool), 1000),
#  (('recordURI', str), 1000),
#  (('providername', str), 1000),
#  (('unitid', str), 1000),
#  (('_version_', int), 1000),
#  (('is_mineral', bool), 993),
#  (('fullscientificname', str), 993),
#  (('names', list), 993),
#  (('country_original', str), 785),
#  (('country', str), 785),
#  (('locality', str), 785),
#  (('stratigraphies', list), 710),
#  (('longitude', float), 589),
#  (('latitude', float), 589),
#  (('coordinates', str), 589),
#  (('collectorname', str), 528),
#  (('stratigraphy', str), 450),
#  (('highertaxon', str), 444),
#  (('higherrank', str), 444),
#  (('highertaxa', list), 444),
#  (('highertaxon_facet', str), 444),
#  (('taxon_hierarchy_string', str), 283),
#  (('taxon_id', int), 283),
#  (('stratigraphytext', str), 267),
#  (('stratigraphytexts', list), 267),
#  (('taxon_id_pbdb', int), 135),
#  (('taxon_id_tol', int), 128),
#  (('images', list), 95),
#  (('image_license', str), 95),
#  (('image_author', str), 95),
#  (('url', str), 95),
#  (('relatedResource', str), 95),
#  (('image_date', str), 94),
#  (('mindat_id', int), 50),
#  (('mindat_url', str), 50)]

# %% [markdown]
# ### Geocase notes
#
# ##### Event-related things
#
# - The only event-like field I can see in the `/solr` endpoint is `last_harvested_processing` (format like "2021-03-25T13:36:50Z").
# - Could query daily on this to get 'updated' records, but it's hard to tell from this angle if it reflects a harvest event (of whatever the source serves up) or if there's actually record/field level updates going on behind the scenes with geocase.
# - There's a `_version_` field for each record, which is handy, but it doesn't translate into a UT timestamp - needs more investigation.
# - No additional audit/field-specific change data or event-adjacent endpoints, as far as I can tell.
#
# #####  IDs
#
# `id` and `occurrenceid` hold the same value, which appears to be a GC internal id?
#
# `unitid` is a registration no. from the original site (in NHM's case, this is older-style accession numbers, rather than a guid - if it was something more persistent, maybe you could use it in conjunction with `datasourceurl` (domain of source catalogue.api) and `/repeat` to get to source data, although that's probably not the point...)
#
# IDs for other systems:
#
# `taxon_id` - not sure where this comes from... internal id?
# `taxon_id_pbdb` - [PBDB identifier](https://paleobiodb.org)
# `taxon_id_tol` - [Tree of Life identifier?](http://tolweb.org/tree/)
# `mindat_id` - [Mindat identifier](https://www.mindat.org)
# `cetaf_identifier` - [CETAF registry institution identifier](http://collections.naturalsciences.be/cpb/nh-collections)

# %% [markdown]
# ___________
# ### 2. CoL
# ____________
#
# 4.4m records at time of testing. Each checklist and name now has its own DOI, which is pretty groovy.
#
# API auth is via GBIF accounts, which is useful and an interesting bit of existing connectivity. CoL also expose both the original submitted species data and the CoLdp ['interpreted' version](https://www.catalogueoflife.org/about/colpipeline#standard-processing).
#
# - [API docs](https://api.catalogueoflife.org/)- Uses [OpenApi specifications](https://swagger.io/specification/). Documented using Swagger. Query/response object schemes are defined, but not much decsription of the purpose of each endpoint past input params and 'Try it out' - probably still working on it as the new API is still under development.
# - [API user mailing list](https://lists.gbif.org/pipermail/col-users/) - nice intro/set of examples for the new API in - [this post](https://lists.gbif.org/pipermail/col-users/2021-March/000004.html)
# - [Overview of the new API architecture](https://www.catalogueoflife.org/about/colpipeline)
# - [Catalogue Of Life Data Package](https://github.com/CatalogueOfLife/coldp#format-comparison): Not sure how relevant it is, but apparently it's a new data upload/download format, based on [frictionless data](https://frictionlessdata.io/) principles)
# - [Web app](https://www.catalogueoflife.org)
#
#
# #### Endpoints
#
# So. Many. Endpoints. Life is much too short to go through them all, the main resources/paths are summarised below. Note that the dataset key to get the most recent version of the CoL database is `3LR` (Swagger doesn't like string values apparently, so current version id at time of writing as int: `2349`, example older version for testing: `2242`)

# %%
# Basic params for the dataset endpoint
col_base = "https://api.catalogueoflife.org"
col_dataset = "/dataset"
col_checklist_2021 = '3LR'
col_checklist_2020 = 2242
col_taxon_key = '5QQJ9'

# %% [markdown]
# `/dataset`:
# * Operations relating to CoL datasets (aka. checklist and all the underlying/contributory datasets), inc. versioning info.
# * Can look at dataset-level data
# * Or search for individual taxa within e.g., the main namelist
# * Combining dataset and name IDs brings back records that include below object-level versioning info, see below for an example.

# %%
# Example call for a name within the main checklist dataset. Note the separate timestamps for last-modified in the taxon 
# record, the name record, the synonym list, and the names within the synonym list.  
col_r = requests.get(col_base + col_dataset + f"/{col_checklist_2021}/taxon/{col_taxon_key}/info")
col_r.json()
# Out:
# {'taxon': {'created': '2020-07-18T09:28:18.006855',
#   'createdBy': 103,
#   'modified': '2020-07-18T09:28:18.006855',
#   'modifiedBy': 103,
#   'datasetKey': 2349,
#   'id': '5QQJ9',
#   'sectorKey': 523,
#   'name': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-09-30T03:30:12.626669',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#    'sectorKey': 523,
#    'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#    'scientificName': 'Picea abies var. abies',
#    'rank': 'variety',
#    'genus': 'Picea',
#    'specificEpithet': 'abies',
#    'infraspecificEpithet': 'abies',
#    'code': 'botanical',
#    'origin': 'source',
#    'type': 'scientific',
#    'parsed': True},
#   'status': 'accepted',
#   'origin': 'source',
#   'parentId': '4HPZF',
#   'remarks': 'IUCN status: LC',
#   'scrutinizer': 'Farjon A.',
#   'scrutinizerDate': '2014-01-31',
#   'extinct': False,
#   'environments': ['terrestrial'],
#   'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#   'label': 'Picea abies var. abies'},
#  'source': {'id': '5QQJ9',
#   'datasetKey': 2349,
#   'sourceId': '4688',
#   'sourceDatasetKey': 1045},
#  'synonyms': [{'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQKJ',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '05ff150f-a7f8-4299-bc76-f1ddaa6ad24b',
#     'sectorKey': 523,
#     'homotypicNameId': '05ff150f-a7f8-4299-bc76-f1ddaa6ad24b',
#     'scientificName': 'Picea excelsa var. integrisquamis',
#     'authorship': 'Carrière',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'excelsa',
#     'infraspecificEpithet': 'integrisquamis',
#     'combinationAuthorship': {'authors': ['Carrière']},
#     'code': 'botanical',
#     'publishedInId': 'a37923e6-b3f0-4e0f-8544-7eae00b66ed8',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea excelsa</i> var. <i>integrisquamis</i> Carrière',
#    'label': 'Picea excelsa var. integrisquamis Carrière'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQKN',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '13a0e64f-9e47-44fc-8c70-487b2c9481a8',
#     'sectorKey': 523,
#     'homotypicNameId': '13a0e64f-9e47-44fc-8c70-487b2c9481a8',
#     'scientificName': 'Picea excelsa var. viminalis',
#     'authorship': '(Alstr.) Casp.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'excelsa',
#     'infraspecificEpithet': 'viminalis',
#     'combinationAuthorship': {'authors': ['Casp.']},
#     'basionymAuthorship': {'authors': ['Alstr.']},
#     'code': 'botanical',
#     'publishedInId': '9de1a3e0-9723-4361-a4f1-664714ced621',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea excelsa</i> var. <i>viminalis</i> (Alstr.) Casp.',
#    'label': 'Picea excelsa var. viminalis (Alstr.) Casp.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '4HQ3T',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '15506aa1-8124-4064-9b8a-6987b75298d0',
#     'sectorKey': 523,
#     'homotypicNameId': '15506aa1-8124-4064-9b8a-6987b75298d0',
#     'scientificName': 'Picea montana',
#     'authorship': 'Schur',
#     'rank': 'species',
#     'genus': 'Picea',
#     'specificEpithet': 'montana',
#     'combinationAuthorship': {'authors': ['Schur']},
#     'code': 'botanical',
#     'publishedInId': 'ac540154-79bc-4e46-8ac2-b1faa2a3c71c',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea montana</i> Schur',
#    'label': 'Picea montana Schur'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '8K9W',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '1b902f57-156b-4b8f-b39f-c6f1869f5dc6',
#     'sectorKey': 523,
#     'homotypicNameId': '1b902f57-156b-4b8f-b39f-c6f1869f5dc6',
#     'scientificName': 'Abies abies',
#     'authorship': '(L.) Rusby',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'abies',
#     'combinationAuthorship': {'authors': ['Rusby']},
#     'basionymAuthorship': {'authors': ['L.']},
#     'code': 'botanical',
#     'publishedInId': '789d79f3-9f13-4150-a33e-c330ac87f114',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Abies abies</i> (L.) Rusby',
#    'label': 'Abies abies (L.) Rusby'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQKG',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '1e790ca2-b33d-4059-bc6e-a668ad4b38ea',
#     'sectorKey': 523,
#     'homotypicNameId': '1e790ca2-b33d-4059-bc6e-a668ad4b38ea',
#     'scientificName': 'Picea excelsa var. erythrocarpa',
#     'authorship': 'Purk.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'excelsa',
#     'infraspecificEpithet': 'erythrocarpa',
#     'combinationAuthorship': {'authors': ['Purk.']},
#     'code': 'botanical',
#     'publishedInId': 'e711ad75-8c56-4346-9dd5-896fd7962728',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea excelsa</i> var. <i>erythrocarpa</i> Purk.',
#    'label': 'Picea excelsa var. erythrocarpa Purk.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5KG8F',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '22e7c75b-d1f6-43a2-a153-cea5d5271476',
#     'sectorKey': 523,
#     'homotypicNameId': '22e7c75b-d1f6-43a2-a153-cea5d5271476',
#     'scientificName': 'Pinus abies subsp. vulgaris',
#     'authorship': 'Voss',
#     'rank': 'subspecies',
#     'genus': 'Pinus',
#     'specificEpithet': 'abies',
#     'infraspecificEpithet': 'vulgaris',
#     'combinationAuthorship': {'authors': ['Voss']},
#     'code': 'botanical',
#     'publishedInId': '778da10f-3937-4a63-80ef-4853410e41db',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Pinus abies</i> subsp. <i>vulgaris</i> Voss',
#    'label': 'Pinus abies subsp. vulgaris Voss'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '63YTD',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '288c0d15-9a86-47e0-9aeb-4b94cc89f95e',
#     'sectorKey': 523,
#     'homotypicNameId': '288c0d15-9a86-47e0-9aeb-4b94cc89f95e',
#     'scientificName': 'Abies alpestris',
#     'authorship': 'Brügger',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'alpestris',
#     'combinationAuthorship': {'authors': ['Brügger']},
#     'code': 'botanical',
#     'publishedInId': '3f61a8b6-ced4-4cb3-b2f7-2c1e98917ca8',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Abies alpestris</i> Brügger',
#    'label': 'Abies alpestris Brügger'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '7MF6T',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '3b2ca0af-db38-4bf3-a9d1-46d09b0133ef',
#     'sectorKey': 523,
#     'homotypicNameId': '3b2ca0af-db38-4bf3-a9d1-46d09b0133ef',
#     'scientificName': 'Picea excelsa var. alpestris',
#     'authorship': '(Brügger) Beissn.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'excelsa',
#     'infraspecificEpithet': 'alpestris',
#     'combinationAuthorship': {'authors': ['Beissn.']},
#     'basionymAuthorship': {'authors': ['Brügger']},
#     'code': 'botanical',
#     'publishedInId': '7bb91d84-11c6-499a-af3d-5c926f5f6298',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea excelsa</i> var. <i>alpestris</i> (Brügger) Beissn.',
#    'label': 'Picea excelsa var. alpestris (Brügger) Beissn.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '8KC6',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '3c83188f-b55f-453a-899f-afe405cabd92',
#     'sectorKey': 523,
#     'homotypicNameId': '3c83188f-b55f-453a-899f-afe405cabd92',
#     'scientificName': 'Abies erythrocarpa',
#     'authorship': 'Purk. ex Nyman',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'erythrocarpa',
#     'combinationAuthorship': {'authors': ['Nyman'], 'exAuthors': ['Purk.']},
#     'code': 'botanical',
#     'publishedInId': '8143221d-6dcd-489c-b3f8-002ae9effd9f',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Abies erythrocarpa</i> Purk. ex Nyman',
#    'label': 'Abies erythrocarpa Purk. ex Nyman'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQM9',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '3f19a1dc-6a89-4fb8-884e-88b109edbfe9',
#     'sectorKey': 523,
#     'homotypicNameId': '3f19a1dc-6a89-4fb8-884e-88b109edbfe9',
#     'scientificName': 'Picea vulgaris var. erythrocarpa',
#     'authorship': '(Purk.) Jacobasch',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'vulgaris',
#     'infraspecificEpithet': 'erythrocarpa',
#     'combinationAuthorship': {'authors': ['Jacobasch']},
#     'basionymAuthorship': {'authors': ['Purk.']},
#     'code': 'botanical',
#     'publishedInId': '51975524-2d72-4791-9049-521bf6b56971',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea vulgaris</i> var. <i>erythrocarpa</i> (Purk.) Jacobasch',
#    'label': 'Picea vulgaris var. erythrocarpa (Purk.) Jacobasch'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '4HZZX',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '4f025147-5be4-4e15-8c52-958926e93396',
#     'sectorKey': 523,
#     'homotypicNameId': '4f025147-5be4-4e15-8c52-958926e93396',
#     'scientificName': 'Pinus abies',
#     'authorship': 'L.',
#     'rank': 'species',
#     'genus': 'Pinus',
#     'specificEpithet': 'abies',
#     'combinationAuthorship': {'authors': ['L.']},
#     'code': 'botanical',
#     'publishedInId': 'b770e61e-1c94-47ac-84a6-a2661466916b',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Pinus abies</i> L.',
#    'label': 'Pinus abies L.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQM8',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '57dda8ba-0e1f-4f6a-ba00-839410947144',
#     'sectorKey': 523,
#     'homotypicNameId': '57dda8ba-0e1f-4f6a-ba00-839410947144',
#     'scientificName': 'Picea vulgaris var. chlorocarpa',
#     'authorship': '(Purk.) Jacobasch',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'vulgaris',
#     'infraspecificEpithet': 'chlorocarpa',
#     'combinationAuthorship': {'authors': ['Jacobasch']},
#     'basionymAuthorship': {'authors': ['Purk.']},
#     'code': 'botanical',
#     'publishedInId': '51975524-2d72-4791-9049-521bf6b56971',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea vulgaris</i> var. <i>chlorocarpa</i> (Purk.) Jacobasch',
#    'label': 'Picea vulgaris var. chlorocarpa (Purk.) Jacobasch'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '63YW2',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5bdb0b00-6c11-4dad-93ec-b6c5e86487d2',
#     'sectorKey': 523,
#     'homotypicNameId': '5bdb0b00-6c11-4dad-93ec-b6c5e86487d2',
#     'scientificName': 'Abies montana',
#     'authorship': 'Nyman',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'montana',
#     'combinationAuthorship': {'authors': ['Nyman']},
#     'code': 'botanical',
#     'publishedInId': '4b85ff07-10c2-4631-aec3-a29c03199417',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Abies montana</i> Nyman',
#    'label': 'Abies montana Nyman'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '63Z7T',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '6273d199-4416-4d3e-8c08-e277174fad13',
#     'sectorKey': 523,
#     'homotypicNameId': '6273d199-4416-4d3e-8c08-e277174fad13',
#     'scientificName': 'Abies subarctica',
#     'authorship': '(Schur) Nyman',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'subarctica',
#     'combinationAuthorship': {'authors': ['Nyman']},
#     'basionymAuthorship': {'authors': ['Schur']},
#     'code': 'botanical',
#     'publishedInId': 'e78d45c1-f8d4-40e3-bdc4-e4a2c997135a',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Abies subarctica</i> (Schur) Nyman',
#    'label': 'Abies subarctica (Schur) Nyman'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '4HQ54',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '62c2c232-39cd-463d-8f22-96eddd01ec81',
#     'sectorKey': 523,
#     'homotypicNameId': '62c2c232-39cd-463d-8f22-96eddd01ec81',
#     'scientificName': 'Picea subarctica',
#     'authorship': 'Schur',
#     'rank': 'species',
#     'genus': 'Picea',
#     'specificEpithet': 'subarctica',
#     'combinationAuthorship': {'authors': ['Schur']},
#     'code': 'botanical',
#     'publishedInId': 'c3e2167f-da09-4640-a9bb-d7469d6f2d40',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea subarctica</i> Schur',
#    'label': 'Picea subarctica Schur'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QQKL',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '6c834313-c659-4431-90a1-759267b466f2',
#     'sectorKey': 523,
#     'homotypicNameId': '6c834313-c659-4431-90a1-759267b466f2',
#     'scientificName': 'Picea excelsa var. nigra',
#     'authorship': '(Loudon) Willk.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'excelsa',
#     'infraspecificEpithet': 'nigra',
#     'combinationAuthorship': {'authors': ['Willk.']},
#     'basionymAuthorship': {'authors': ['Loudon']},
#     'code': 'botanical',
#     'publishedInId': 'f794ca0d-a688-4846-92a6-c5660fc1a515',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea excelsa</i> var. <i>nigra</i> (Loudon) Willk.',
#    'label': 'Picea excelsa var. nigra (Loudon) Willk.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5QR6B',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '74d9d02e-e1dc-4344-b1b9-af110388bee0',
#     'sectorKey': 523,
#     'homotypicNameId': '74d9d02e-e1dc-4344-b1b9-af110388bee0',
#     'scientificName': 'Pinus abies var. viminalis',
#     'authorship': '(Alstr.) Lilj.',
#     'rank': 'variety',
#     'genus': 'Pinus',
#     'specificEpithet': 'abies',
#     'infraspecificEpithet': 'viminalis',
#     'combinationAuthorship': {'authors': ['Lilj.']},
#     'basionymAuthorship': {'authors': ['Alstr.']},
#     'code': 'botanical',
#     'publishedInId': '92507ca2-b845-43c3-a2c9-9dfb85069a1e',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Pinus abies</i> var. <i>viminalis</i> (Alstr.) Lilj.',
#    'label': 'Pinus abies var. viminalis (Alstr.) Lilj.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '7MF6H',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '798656a8-5793-4cc3-a1f3-c56cc4a8a3e9',
#     'sectorKey': 523,
#     'homotypicNameId': '798656a8-5793-4cc3-a1f3-c56cc4a8a3e9',
#     'scientificName': 'Picea vulgaris var. viminalis',
#     'authorship': '(Alstr.) Casp.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'vulgaris',
#     'infraspecificEpithet': 'viminalis',
#     'combinationAuthorship': {'authors': ['Casp.']},
#     'basionymAuthorship': {'authors': ['Alstr.']},
#     'code': 'botanical',
#     'publishedInId': '89f6af9a-accc-4e00-884d-f9288a79302b',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea vulgaris</i> var. <i>viminalis</i> (Alstr.) Casp.',
#    'label': 'Picea vulgaris var. viminalis (Alstr.) Casp.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '77J2C',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '81e6a812-a011-4fbe-967a-109a0f5cf68d',
#     'sectorKey': 523,
#     'homotypicNameId': '81e6a812-a011-4fbe-967a-109a0f5cf68d',
#     'scientificName': 'Picea vulgaris',
#     'authorship': 'Link',
#     'rank': 'species',
#     'genus': 'Picea',
#     'specificEpithet': 'vulgaris',
#     'combinationAuthorship': {'authors': ['Link']},
#     'code': 'botanical',
#     'publishedInId': '5ef4b260-a426-4f95-b472-3821f34486b5',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea vulgaris</i> Link',
#    'label': 'Picea vulgaris Link'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '7MF73',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '84b10436-a871-49c8-b97a-ce506f3bdb6c',
#     'sectorKey': 523,
#     'homotypicNameId': '84b10436-a871-49c8-b97a-ce506f3bdb6c',
#     'scientificName': 'Picea vulgaris var. europaea',
#     'authorship': 'Tepl.',
#     'rank': 'variety',
#     'genus': 'Picea',
#     'specificEpithet': 'vulgaris',
#     'infraspecificEpithet': 'europaea',
#     'combinationAuthorship': {'authors': ['Tepl.']},
#     'code': 'botanical',
#     'publishedInId': '00359a00-e39a-43bf-922d-ad9e5dbe17d3',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
#     'extinct': False,
#     'environments': ['terrestrial'],
#     'labelHtml': '<i>Picea abies</i> var. <i>abies</i>',
#     'label': 'Picea abies var. abies'},
#    'homotypic': False,
#    'labelHtml': '<i>Picea vulgaris</i> var. <i>europaea</i> Tepl.',
#    'label': 'Picea vulgaris var. europaea Tepl.'},
#   {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '8KBF',
#    'sectorKey': 523,
#    'name': {'created': '2020-07-18T09:28:27.704694',
#     'createdBy': 103,
#     'modified': '2020-09-30T03:30:12.626669',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '8adae5d6-0a53-450f-b300-668280426064',
#     'sectorKey': 523,
#     'homotypicNameId': '8adae5d6-0a53-450f-b300-668280426064',
#     'scientificName': 'Abies cinerea',
#     'authorship': 'Borkh.',
#     'rank': 'species',
#     'genus': 'Abies',
#     'specificEpithet': 'cinerea',
#     'combinationAuthorship': {'authors': ['Borkh.']},
#     'code': 'botanical',
#     'publishedInId': '38ec9e6c-08a4-49ad-a1f2-e256cdf99b7c',
#     'origin': 'source',
#     'type': 'scientific',
#     'parsed': True},
#    'status': 'synonym',
#    'origin': 'source',
#    'parentId': '5QQJ9',
#    'accepted': {'created': '2020-07-18T09:28:18.006855',
#     'createdBy': 103,
#     'modified': '2020-07-18T09:28:18.006855',
#     'modifiedBy': 103,
#     'datasetKey': 2349,
#     'id': '5QQJ9',
#     'sectorKey': 523,
#     'name': {'created': '2020-07-18T09:28:18.006855',
#      'createdBy': 103,
#      'modified': '2020-09-30T03:30:12.626669',
#      'modifiedBy': 103,
#      'datasetKey': 2349,
#      'id': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'sectorKey': 523,
#      'homotypicNameId': 'aaaff60d-63da-434e-88cc-22d52dc3b45e',
#      'scientificName': 'Picea abies var. abies',
#      'rank': 'variety',
#      'genus': 'Picea',
#      'specificEpithet': 'abies',
#      'infraspecificEpithet': 'abies',
#      'code': 'botanical',
#      'origin': 'source',
#      'type': 'scientific',
#      'parsed': True},
#     'status': 'accepted',
#     'origin': 'source',
#     'parentId': '4HPZF',
#     'remarks': 'IUCN status: LC',
#     'scrutinizer': 'Farjon A.',
#     'scrutinizerDate': '2014-01-31',
# ...
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '9e7214a3-3e06-4af4-a673-1103db9661af',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Lawson'}],
#     'issued': {'date-parts': [[1866]]},
#     'container-title': 'In: Pinetum Brit.: 159.'},
#    'citation': 'Lawson. In: Pinetum Brit.: 159. (1866).',
#    'year': 1866,
#    'parsed': True},
#   '4b85ff07-10c2-4631-aec3-a29c03199417': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '4b85ff07-10c2-4631-aec3-a29c03199417',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Nyman'}],
#     'issued': {'date-parts': [[1865]]},
#     'container-title': 'In: Syll. Fl. Suppl.: 602.'},
#    'citation': 'Nyman. In: Syll. Fl. Suppl.: 602. (1865).',
#    'year': 1865,
#    'parsed': True},
#   'bdea0ce1-2a60-4438-8b50-0db4af16e51e': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'bdea0ce1-2a60-4438-8b50-0db4af16e51e',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Th. Fr.'}],
#     'issued': {'date-parts': [[1867]]},
#     'container-title': 'In: Bot. Not. 1867: 56.'},
#    'citation': 'Th. Fr. In: Bot. Not. 1867: 56. (1867).',
#    'year': 1867,
#    'parsed': True},
#   'e39560e6-8666-4efb-986c-9a7c3532585a': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'e39560e6-8666-4efb-986c-9a7c3532585a',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Willk.'}],
#     'issued': {'date-parts': [[1875]]},
#     'container-title': 'In: Forst. Fl.: 66.'},
#    'citation': 'Willk. In: Forst. Fl.: 66. (1875).',
#    'year': 1875,
#    'parsed': True},
#   'e40b2ae9-75b6-4880-a19d-8bbf0774413a': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'e40b2ae9-75b6-4880-a19d-8bbf0774413a',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Loudon ex Endl.'}],
#     'issued': {'date-parts': [[1847]]},
#     'container-title': 'In: Syn. Conif.: 117.'},
#    'citation': 'Loudon ex Endl. In: Syn. Conif.: 117. (1847).',
#    'year': 1847,
#    'parsed': True},
#   'c7162ac4-59ca-401f-bc75-d29ffe974500': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'c7162ac4-59ca-401f-bc75-d29ffe974500',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Lindl. & Gordon'}],
#     'issued': {'date-parts': [[1850]]},
#     'container-title': 'In: J. Hort. Soc. London 5: 212.'},
#    'citation': 'Lindl. & Gordon. In: J. Hort. Soc. London 5: 212. (1850).',
#    'year': 1850,
#    'parsed': True},
#   'b770e61e-1c94-47ac-84a6-a2661466916b': {'created': '2020-07-18T09:28:11.192938',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:11.192938',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'b770e61e-1c94-47ac-84a6-a2661466916b',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'L.'}],
#     'issued': {'date-parts': [[1753]]},
#     'container-title': 'In: Sp. Pl. 2: 1002.'},
#    'citation': 'L. In: Sp. Pl. 2: 1002. (1753).',
#    'year': 1753,
#    'parsed': True},
#   'c3e2167f-da09-4640-a9bb-d7469d6f2d40': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'c3e2167f-da09-4640-a9bb-d7469d6f2d40',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Schur'}],
#     'issued': {'date-parts': [[1853]]},
#     'container-title': 'In: Sert. Fl. Transsilv. 6: 69., n. 2630.'},
#    'citation': 'Schur. In: Sert. Fl. Transsilv. 6: 69., n. 2630. (1853).',
#    'year': 1853,
#    'parsed': True},
#   '0cb8db62-2346-4d13-bd0f-f615ab223091': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '0cb8db62-2346-4d13-bd0f-f615ab223091',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Lam.'}],
#     'issued': {'date-parts': [[1778]]},
#     'container-title': 'In: Fl. françoise 2: 202.'},
#    'citation': 'Lam. In: Fl. françoise 2: 202. (1778).',
#    'year': 1778,
#    'parsed': True},
#   '688ff49f-5dbe-4d57-b261-786e0b8da028': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '688ff49f-5dbe-4d57-b261-786e0b8da028',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Salisb.'}],
#     'issued': {'date-parts': [[1796]]},
#     'container-title': 'In: Prodr. Chap. Allerton: 399.'},
#    'citation': 'Salisb. In: Prodr. Chap. Allerton: 399. (1796).',
#    'year': 1796,
#    'parsed': True},
#   '87df8423-aa01-4652-8958-b7301e3b3771': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '87df8423-aa01-4652-8958-b7301e3b3771',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Henry', 'given': 'A.'}],
#     'issued': {'date-parts': [[1913]]},
#     'container-title': 'In: Elwes & Henry, Trees Gr. Brit. Ireland 6: 1360.'},
#    'citation': 'A. Henry. In: Elwes & Henry, Trees Gr. Brit. Ireland 6: 1360. (1913).',
#    'year': 1913,
#    'parsed': True},
#   '778da10f-3937-4a63-80ef-4853410e41db': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '778da10f-3937-4a63-80ef-4853410e41db',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Voss'}],
#     'issued': {'date-parts': [[1913]]},
#     'container-title': 'In: Putlitz & Meyer, Landlex. 4: 770.'},
#    'citation': 'Voss. In: Putlitz & Meyer, Landlex. 4: 770. (1913).',
#    'year': 1913,
#    'parsed': True},
#   'a237aae3-202b-46ac-a1de-ea1cbb4ed633': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'a237aae3-202b-46ac-a1de-ea1cbb4ed633',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Mill.'}],
#     'issued': {'date-parts': [[1768]]},
#     'container-title': 'In: Gard. Dict., ed. 8: Abies No. 2.'},
#    'citation': 'Mill. In: Gard. Dict., ed. 8: Abies No. 2. (1768).',
#    'year': 1768,
#    'parsed': True},
#   'd8bce4ae-e048-473d-8b22-a5f337bbf4f2': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'd8bce4ae-e048-473d-8b22-a5f337bbf4f2',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Poir.'}],
#     'issued': {'date-parts': [[1805]]},
#     'container-title': 'In: Lamarck, Encycl. 6: 518.'},
#    'citation': 'Poir. In: Lamarck, Encycl. 6: 518. (1805).',
#    'year': 1805,
#    'parsed': True},
#   'e811e52d-fdc6-46e7-a6db-f85ab424145a': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'e811e52d-fdc6-46e7-a6db-f85ab424145a',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Gilib.'}],
#     'issued': {'date-parts': [[1792]]},
#     'container-title': 'In: Exerc. Phytol. 2: 411.'},
#    'citation': 'Gilib. In: Exerc. Phytol. 2: 411. (1792).',
#    'year': 1792,
#    'parsed': True},
#   '51975524-2d72-4791-9049-521bf6b56971': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '51975524-2d72-4791-9049-521bf6b56971',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Jacobasch'}],
#     'issued': {'date-parts': [[1882]]},
#     'container-title': 'In: Sitzber. Bot. Vereins Prov. Brandenburg 24: 98.'},
#    'citation': 'Jacobasch. In: Sitzber. Bot. Vereins Prov. Brandenburg 24: 98. (1882).',
#    'year': 1882,
#    'parsed': True},
#   '8143221d-6dcd-489c-b3f8-002ae9effd9f': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '8143221d-6dcd-489c-b3f8-002ae9effd9f',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Purk. ex Nyman'}],
#     'issued': {'date-parts': [[1881]]},
#     'container-title': 'In: Consp. Fl. Europ. 3: 674.'},
#    'citation': 'Purk. ex Nyman. In: Consp. Fl. Europ. 3: 674. (1881).',
#    'year': 1881,
#    'parsed': True},
#   'f3382ecb-c56e-4816-9c1a-5e82dad8752f': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'f3382ecb-c56e-4816-9c1a-5e82dad8752f',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Chiov.'}],
#     'issued': {'date-parts': [[1935]]},
#     'container-title': 'In: Fl. Alp. Lepont. Occid. 3: 16.'},
#    'citation': 'Chiov. In: Fl. Alp. Lepont. Occid. 3: 16. (1935).',
#    'year': 1935,
#    'parsed': True},
#   '3f61a8b6-ced4-4cb3-b2f7-2c1e98917ca8': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '3f61a8b6-ced4-4cb3-b2f7-2c1e98917ca8',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Brügger'}],
#     'issued': {'date-parts': [[1886]]},
#     'container-title': 'In: Jahresber. Naturf. Ges. Graubündens, ser. 2, 29: 167.'},
#    'citation': 'Brügger. In: Jahresber. Naturf. Ges. Graubündens, ser. 2, 29: 167. (1886).',
#    'year': 1886,
#    'parsed': True},
#   '5a1fe15f-3a0c-4de1-b0c9-d8d2c86acdbc': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '5a1fe15f-3a0c-4de1-b0c9-d8d2c86acdbc',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Stein'}],
#     'issued': {'date-parts': [[1887]]},
#     'container-title': 'In: Gartenfl. 37: 346.'},
#    'citation': 'Stein. In: Gartenfl. 37: 346. (1887).',
#    'year': 1887,
#    'parsed': True},
#   'c305b5e2-b624-48a9-a922-11b8c61c2ca7': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'c305b5e2-b624-48a9-a922-11b8c61c2ca7',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Lindq.'}],
#     'issued': {'date-parts': [[1948]]},
#     'container-title': 'In: Acta Horti Berg. 14 (8): 308.'},
#    'citation': 'Lindq. In: Acta Horti Berg. 14 (8): 308. (1948).',
#    'year': 1948,
#    'parsed': True},
#   'e5af63bd-4a50-4b46-8600-4d6822eb5525': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'e5af63bd-4a50-4b46-8600-4d6822eb5525',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Alstr.'}],
#     'issued': {'date-parts': [[1777]]},
#     'container-title': 'In: Kongl. Vetensk. Acad. Handl. 38: 310, t. 8, 9.'},
#    'citation': 'Alstr. In: Kongl. Vetensk. Acad. Handl. 38: 310, t. 8, 9. (1777).',
#    'year': 1777,
#    'parsed': True},
#   '89f6af9a-accc-4e00-884d-f9288a79302b': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '89f6af9a-accc-4e00-884d-f9288a79302b',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Casp.'}],
#     'issued': {'date-parts': [[1873]]},
#     'container-title': 'In: Schrift. Phys.-ökon. Ges. Königsberg 14: 125.'},
#    'citation': 'Casp. In: Schrift. Phys.-ökon. Ges. Königsberg 14: 125. (1873).',
#    'year': 1873,
#    'parsed': True},
#   'a37923e6-b3f0-4e0f-8544-7eae00b66ed8': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'a37923e6-b3f0-4e0f-8544-7eae00b66ed8',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Carrière'}],
#     'issued': {'date-parts': [[1855]]},
#     'container-title': 'In: Traité Gén. Conif.: 246.'},
#    'citation': 'Carrière. In: Traité Gén. Conif.: 246. (1855).',
#    'year': 1855,
#    'parsed': True},
#   '18a596f6-a6bf-4f3c-83b8-4373aff0d716': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '18a596f6-a6bf-4f3c-83b8-4373aff0d716',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'A. Dietr.'}],
#     'issued': {'date-parts': [[1824]]},
#     'container-title': 'In: Fl. Gegend Berlin 2: 795.'},
#    'citation': 'A. Dietr. In: Fl. Gegend Berlin 2: 795. (1824).',
#    'year': 1824,
#    'parsed': True},
#   '7bb91d84-11c6-499a-af3d-5c926f5f6298': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '7bb91d84-11c6-499a-af3d-5c926f5f6298',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Beissn.'}],
#     'issued': {'date-parts': [[1891]]},
#     'container-title': 'In: Handb. Nadelholzk.: 357.'},
#    'citation': 'Beissn. In: Handb. Nadelholzk.: 357. (1891).',
#    'year': 1891,
#    'parsed': True},
#   'e711ad75-8c56-4346-9dd5-896fd7962728': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'e711ad75-8c56-4346-9dd5-896fd7962728',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Purk.'}],
#     'issued': {'date-parts': [[1877]]},
#     'container-title': 'In: Allg. Forst-Jagdzeit. 53: 1-10.'},
#    'citation': 'Purk. In: Allg. Forst-Jagdzeit. 53: 1-10. (1877).',
#    'year': 1877,
#    'parsed': True},
#   '92507ca2-b845-43c3-a2c9-9dfb85069a1e': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '92507ca2-b845-43c3-a2c9-9dfb85069a1e',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Lilj.'}],
#     'issued': {'date-parts': [[1792]]},
#     'container-title': 'In: Utk. Svensk Fl.: 208.'},
#    'citation': 'Lilj. In: Utk. Svensk Fl.: 208. (1792).',
#    'year': 1792,
#    'parsed': True},
#   'd535931b-d8d0-48d6-a087-15b12efa0830': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': 'd535931b-d8d0-48d6-a087-15b12efa0830',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Schröt.'}],
#     'issued': {'date-parts': [[1898]]},
#     'container-title': 'In: Vierteljahresschr. Naturf. Ges. Zürich 43: 142, 232.'},
#    'citation': 'Schröt. In: Vierteljahresschr. Naturf. Ges. Zürich 43: 142, 232. (1898).',
#    'year': 1898,
#    'parsed': True},
#   '457afcf7-fea7-4fcc-a65f-ad8eea649c02': {'created': '2020-07-18T09:28:18.006855',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:18.006855',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '457afcf7-fea7-4fcc-a65f-ad8eea649c02',
#    'sectorKey': 523,
#    'csl': {'author': [{'family': 'Schmidt', 'given': 'P.A.'}],
#     'issued': {'date-parts': [[1988]]},
#     'container-title': 'In: Haussknechtia 4: 38.'},
#    'citation': 'P.A. Schmidt. In: Haussknechtia 4: 38. (1988).',
#    'year': 1988,
#    'parsed': True},
#   '9de1a3e0-9723-4361-a4f1-664714ced621': {'created': '2020-07-18T09:28:27.704694',
#    'createdBy': 103,
#    'modified': '2020-07-18T09:28:27.704694',
#    'modifiedBy': 103,
#    'datasetKey': 2349,
#    'id': '9de1a3e0-9723-4361-a4f1-664714ced621',
#    'sectorKey': 523,
#    'csl': {'author': [{'literal': 'Casp.'}],
#     'issued': {'date-parts': [[1878]]},
#     'container-title': 'In: Schrift. Phys.-ökon. Ges. Königsberg 19: 153.'},
#    'citation': 'Casp. In: Schrift. Phys.-ökon. Ges. Königsberg 19: 153. (1878).',
#    'year': 1878,
#    'parsed': True}}}

# %% [markdown]
# * Some summary counts are available for import operations (example below) - assume there's more sophisticated logging on the admin side of things, but could watch this for crude indicator of changes/updates to the checklist dataset (assuming that the main events of interest from CoL are based around name designations)
# * Weirdly hard to find previous keys for the same dataset though? Unless I'm missing something...

# %%
# Example calls for the import records associated with two differenbt versions of the CoL checklist
col_r_2021 = requests.get(col_base + col_dataset + f"/{col_checklist_2021}/import").json()
col_r_2020 = requests.get(col_base + col_dataset + f"/{col_checklist_2020}/import").json()

# Earlier version
col_r_2020
# Out:
# [{'datasetKey': 3,
#   'attempt': 23,
#   'job': 'ProjectRelease',
#   'state': 'finished',
#   'started': '2020-12-01T15:26:12.145442',
#   'finished': '2020-12-01T17:56:50.036638',
#   'createdBy': 101,
#   'bareNameCount': 325,
#   'distributionCount': 2038375,
#   'estimateCount': 1257,
#   'mediaCount': 0,
#   'nameCount': 3982070,
#   'referenceCount': 2257009,
#   'synonymCount': 1721671,
#   'taxonCount': 2260074,
#   'treatmentCount': 0,
#   'typeMaterialCount': 0,
#   'vernacularCount': 457308,
#   'distributionsByGazetteerCount': {'text': 2038368, 'iso': 7},
#   'extinctTaxaByRankCount': {'species': 38297,
#    'infraspecific name': 539,
#    'genus': 175,
#    'subspecies': 73,
#    'variety': 41,
#    'subfamily': 13,
#    'family': 9,
#    'form': 6,
#    'tribe': 5},
#   'namesByCodeCount': {'zoological': 2333655,
#    'botanical': 1465114,
#    'bacterial': 15360,
#    'virus': 8009},
#   'namesByRankCount': {'species': 3306125,
#    'genus': 185541,
#    'subspecies': 182974,
#    'variety': 171912,
#    'infraspecific name': 62776,
#    'form': 30811,
#    'unranked': 13711,
#    'family': 12613,
#    'subgenus': 7499,
#    'order': 1821,
#    'subfamily': 1544,
#    'superfamily': 1124,
#    'tribe': 800,
#    'morph': 610,
#    'subvariety': 473,
#    'class': 436,
#    'infraorder': 330,
#    'section': 238,
#    'subtribe': 165,
#    'phylum': 134,
#    'suborder': 119,
#    'subform': 89,
#    'proles': 84,
#    'aberration': 49,
#    'subclass': 26,
#    'subphylum': 17,
#    'superorder': 16,
#    'kingdom': 9,
#    'subsection': 5,
#    'series': 5,
#    'forma specialis': 5,
#    'subkingdom': 2,
#    'superclass': 2,
#    'infraclass': 2,
#    'subseries': 1,
#    'infrageneric name': 1,
#    'natio': 1},
#   'namesByStatusCount': {'acceptable': 238422,
#    'unacceptable': 12490,
#    'not established': 3229,
#    'established': 3207,
#    'manuscript': 1504,
#    'rejected': 280,
#    'doubtful': 124,
#    'conserved': 85},
#   'namesByTypeCount': {'scientific': 3974003, 'virus': 8067},
#   'synonymsByRankCount': {'species': 1409493,
#    'variety': 147950,
#    'subspecies': 86792,
#    'form': 30005,
#    'infraspecific name': 23326,
#    'unranked': 13710,
#    'genus': 6107,
#    'family': 1232,
#    'morph': 610,
#    'subvariety': 473,
#    'subfamily': 342,
#    'subgenus': 297,
#    'order': 295,
#    'infraorder': 251,
#    'section': 238,
#    'tribe': 140,
#    'subform': 89,
#    'proles': 84,
#    'class': 51,
#    'aberration': 49,
#    'suborder': 47,
#    'subtribe': 19,
#    'superfamily': 18,
#    'phylum': 15,
#    'superorder': 13,
#    'subclass': 6,
#    'subsection': 5,
#    'series': 5,
#    'forma specialis': 5,
#    'kingdom': 1,
#    'subseries': 1,
#    'infrageneric name': 1,
#    'natio': 1},
#   'taxaByRankCount': {'species': 1896632,
#    'genus': 179430,
#    'subspecies': 96182,
#    'infraspecific name': 39450,
#    'variety': 23962,
#    'family': 11227,
#    'subgenus': 7202,
#    'order': 1481,
#    'subfamily': 1164,
#    'superfamily': 1106,
#    'form': 806,
#    'tribe': 647,
#    'class': 374,
#    'subtribe': 135,
#    'phylum': 117,
#    'suborder': 70,
#    'infraorder': 34,
#    'subclass': 20,
#    'subphylum': 17,
#    'kingdom': 8,
#    'superorder': 3,
#    'subkingdom': 2,
#    'superclass': 2,
#    'infraclass': 2,
#    'unranked': 1},
#   'usagesByStatusCount': {'accepted': 2171071,
#    'synonym': 1630694,
#    'provisionally accepted': 89003,
#    'ambiguous synonym': 80847,
#    'misapplied': 10130},
#   'usagesByOriginCount': {'source': 3974184,
#    'implicit name': 7060,
#    'user': 501},
#   'vernacularsByLanguageCount': {'eng': 135046,
#    'cmn': 60319,
#    'spa': 24107,
#    'deu': 16560,
#    'fra': 15919,
#    'por': 13440,
#    'jpn': 12920,
#    'est': 10475,
#    'msa': 9490,
#    'rus': 8475,
#    'ita': 6075,
#    'dan': 6063,
#    'fin': 5536,
#    'ces': 5327,
#    'ara': 3948,
#    'ceb': 3810,
#    'tgl': 3796,
#    'tam': 3092,
#    'nld': 2994,
#    'mal': 2826,
#    'ell': 2663,
#    'afr': 2522,
#    'swe': 2290,
#    'pol': 2012,
#    'tur': 1729,
#    'kor': 1591,
#    'vie': 1543,
#    'bik': 1523,
#    'tha': 1411,
#    'ilo': 1184,
#    'war': 1171,
#    'fij': 1110,
#    'mar': 1092,
#    'zho': 1025,
#    'swa': 1019,
#    'tel': 1015,
#    'sqi': 1001,
#    'cal': 954,
#    'daw': 944,
#    'smo': 923,
#    'hrv': 922,
#    'hil': 883,
#    'ben': 878,
#    'mlt': 860,
#    'hin': 839,
#    'tah': 832,
#    'wol': 764,
#    'srp': 752,
#    'sin': 733,
#    'nor': 721,
#    'cat': 707,
#    'kan': 694,
#    'sgd': 658,
#    'khm': 642,
#    'rom': 605,
#    'jav': 589,
#    'div': 578,
#    'fas': 538,
#    'haw': 517,
#    'cbq': 509,
#    'pap': 508,
#    'mah': 497,
#    'iku': 485,
#    'pau': 482,
#    'cbk': 479,
#    'nlg': 443,
#    'nya': 417,
#    'guj': 414,
#    'nep': 410,
#    'rol': 409,
#    'som': 399,
#    'isl': 396,
#    'tbk': 384,
#    'mya': 353,
#    'tkl': 340,
#    'ind': 334,
#    'fao': 330,
#    'cos': 314,
#    'hun': 309,
#    'heb': 301,
#    'mlg': 289,
#    'ewe': 288,
#    'agn': 276,
#    'keb': 274,
#    'kim': 254,
#    'cjk': 252,
#    'cym': 250,
#    'sco': 250,
#    'slv': 240,
#    'cgc': 228,
#    'hau': 223,
#    'pmt': 223,
#    'ace': 219,
#    'mri': 209,
#    'way': 191,
#    'pam': 189,
#    'ton': 188,
#    'ivv': 185,
#    'ukr': 184,
#    'pag': 181,
#    'lit': 161,
#    'yue': 160,
#    'fon': 158,
#    'srm': 155,
#    'mrv': 153,
#    'asm': 152,
#    'pan': 146,
#    'nob': 140,
#    'nno': 138,
#    'ray': 138,
#    'mon': 135,
#    'skg': 135,
#    'ori': 133,
#    'bul': 131,
#    'lav': 131,
#    'slk': 126,
#    'kdk': 125,
#    'bem': 124,
#    'rap': 118,
#    'grn': 114,
#    'srn': 114,
#    'yor': 112,
#    'mnk': 110,
#    'sus': 108,
#    'kri': 106,
#    'ron': 106,
#    'wls': 100,
#    'hai': 96,
#    'nup': 95,
#    'dip': 94,
#    'niu': 86,
#    'zne': 86,
#    'bcn': 85,
#    'cha': 85,
#    'loo': 84,
#    'aze': 81,
#    'guc': 81,
#    'kau': 81,
#    'fan': 78,
#    'hye': 75,
#    'fwa': 74,
#    'gle': 73,
#    'vif': 71,
#    'iba': 68,
#    'dyo': 65,
#    'kir': 65,
#    'ibo': 63,
#    'mos': 63,
#    'tvl': 61,
#    'dnj': 55,
#    'fry': 55,
#    'tum': 53,
#    'snd': 50,
#    'kat': 49,
#    'kok': 47,
#    'urd': 47,
#    'mni': 46,
#    'tsi': 45,
#    'bis': 44,
#    'men': 44,
#    'bbc': 43,
#    'hei': 43,
#    'jaz': 43,
#    'koo': 43,
#    'luo': 43,
#    'uzb': 43,
#    'cre': 41,
#    'cgg': 40,
#    'kaz': 39,
#    'shk': 39,
#    'ada': 38,
#    'nus': 38,
#    'yao': 38,
#    'tuv': 37,
#    'smk': 35,
#    'snk': 34,
#    'lia': 33,
#    'kha': 31,
#    'ven': 31,
#    'ems': 30,
#    'seh': 30,
#    'bci': 29,
#    'glv': 28,
#    'kas': 28,
#    'piz': 27,
#    'amh': 26,
#    'nyo': 25,
#    'kal': 24,
#    'pkb': 24,
#    'bck': 23,
#    'elo': 23,
#    'nyh': 23,
#    'mkd': 22,
#    'goa': 21,
#    'gni': 20,
#    'ung': 19,
#    'wmt': 18,
#    'bvb': 17,
#    'adj': 16,
#    'bal': 16,
#    'tox': 16,
#    'bod': 15,
#    'gla': 15,
#    'thy': 15,
#    'alz': 14,
#    'bam': 14,
#    'glg': 14,
#    'ibg': 14,
#    'nyf': 14,
#    'rug': 14,
#    'scn': 14,
#    'dmm': 13,
#    'nem': 13,
#    'fub': 12,
#    'kom': 12,
#    'loz': 12,
#    'nuk': 12,
#    'fil': 11,
#    'plu': 11,
#    'que': 11,
#    'bta': 10,
#    'eus': 10,
#    'kos': 10,
#    'run': 10,
#    'chh': 9,
#    'epo': 9,
#    'txy': 9,
#    'aka': 8,
#    'chv': 8,
#    'kky': 8,
#    'miq': 8,
#    'lke': 7,
#    'lno': 7,
#    'rub': 7,
#    'sah': 7,
#    'bin': 6,
#    'mcn': 6,
#    'mug': 6,
#    'orm': 6,
#    'dig': 5,
#    'jbu': 5,
#    'mcs': 5,
#    'mua': 5,
#    'oka': 5,
#    'ona': 5,
#    'tui': 5,
#    'bre': 4,
#    'efi': 4,
#    'kik': 4,
#    'lao': 4,
#    'luy': 4,
#    'meu': 4,
#    'shs': 4,
#    'sun': 4,
#    'arw': 3,
#    'bua': 3,
#    'dua': 3,
#    'kbl': 3,
#    'khq': 3,
#    'kvf': 3,
#    'lin': 3,
#    'mer': 3,
#    'nie': 3,
#    'nzi': 3,
#    'pih': 3,
#    'ryu': 3,
#    'saq': 3,
#    'tfi': 3,
#    'tir': 3,
#    'twi': 3,
#    'ain': 2,
#    'bdm': 2,
#    'dzo': 2,
#    'enq': 2,
#    'foi': 2,
#    'int': 2,
#    'kam': 2,
#    'kwc': 2,
#    'lan': 2,
#    'lop': 2,
#    'mau': 2,
#    'mey': 2,
#    'mlf': 2,
#    'mlj': 2,
#    'mui': 2,
#    'nan': 2,
#    'oci': 2,
#    'res': 2,
#    'sbd': 2,
#    'sjm': 2,
#    'umb': 2,
#    'xho': 2,
#    'alq': 1,
#    'avi': 1,
#    'bib': 1,
#    'bnc': 1,
#    'bos': 1,
#    'bqp': 1,
#    'bsy': 1,
#    'bus': 1,
#    'bvf': 1,
#    'cnr': 1,
#    'dai': 1,
#    'dtp': 1,
#    'ebg': 1,
#    'eee': 1,
#    'esn': 1,
#    'etu': 1,
#    'gbp': 1,
#    'gdk': 1,
#    'hak': 1,
#    'hmo': 1,
#    'inn': 1,
#    'ker': 1,
#    'kie': 1,
#    'kru': 1,
#    'ksp': 1,
#    'kxd': 1,
#    'kzd': 1,
#    'kzr': 1,
#    'lij': 1,
#    'lil': 1,
#    'lol': 1,
#    'lue': 1,
#    'lug': 1,
#    'mqx': 1,
#    'ngc': 1,
#    'ruc': 1,
#    'sie': 1,
#    'skr': 1,
#    'swy': 1,
#    'tbw': 1,
#    'tdv': 1,
#    'thv': 1,
#    'tmh': 1,
#    'tpw': 1,
#    'tuk': 1,
#    'tuo': 1,
#    'xal': 1,
#    'zul': 1},
#   'origin': 'managed',
#   'verbatimCount': 0,
#   'usagesCount': 3981745,
#   'taxonConceptRelationsCount': 0,
#   'speciesInteractionsCount': 0,
#   'nameRelationsCount': 0}]

# %%
# Later version
col_r_2021
# Out:
# [{'datasetKey': 3,
#   'attempt': 66,
#   'job': 'ProjectRelease',
#   'state': 'finished',
#   'started': '2021-10-18T18:42:48.624667',
#   'finished': '2021-10-19T00:46:20.432851',
#   'createdBy': 102,
#   'bareNameCount': 1361,
#   'distributionCount': 1936307,
#   'estimateCount': 1258,
#   'mediaCount': 0,
#   'nameCount': 4418386,
#   'referenceCount': 2483978,
#   'synonymCount': 1985107,
#   'taxonCount': 2431918,
#   'treatmentCount': 0,
#   'typeMaterialCount': 0,
#   'vernacularCount': 471815,
#   'distributionsByGazetteerCount': {'text': 1536590,
#    'mrgid': 393537,
#    'iso': 6180},
#   'extinctTaxaByRankCount': {'species': 112761,
#    'genus': 13376,
#    'subspecies': 3897,
#    'variety': 2633,
#    'family': 1380,
#    'subgenus': 492,
#    'subfamily': 451,
#    'superfamily': 185,
#    'form': 172,
#    'tribe': 62,
#    'order': 48,
#    'suborder': 34,
#    'subvariety': 12,
#    'infraorder': 7,
#    'subclass': 6,
#    'class': 4,
#    'infraclass': 4,
#    'subtribe': 4,
#    'supertribe': 3,
#    'infraspecific name': 2,
#    'superorder': 1},
#   'namesByCodeCount': {'zoological': 2674884,
#    'botanical': 1608281,
#    'bacterial': 15360,
#    'virus': 7986},
#   'namesByRankCount': {'species': 3655535,
#    'subspecies': 220032,
#    'genus': 215448,
#    'variety': 190502,
#    'infraspecific name': 42902,
#    'form': 32973,
#    'unranked': 14599,
#    'family': 14598,
#    'subgenus': 14217,
#    'subfamily': 5847,
#    'tribe': 3942,
#    'order': 1967,
#    'superfamily': 1459,
#    'subtribe': 987,
#    'infrageneric name': 557,
#    'subvariety': 504,
#    'class': 462,
#    'infraorder': 457,
#    'suborder': 432,
#    'section': 249,
#    'phylum': 135,
#    'proles': 98,
#    'subclass': 96,
#    'subform': 89,
#    'superorder': 48,
#    'infratribe': 41,
#    'infrasubspecific name': 32,
#    'subphylum': 31,
#    'parvorder': 29,
#    'aberration': 28,
#    'infraclass': 20,
#    'kingdom': 10,
#    'subterclass': 10,
#    'nanorder': 10,
#    'supertribe': 6,
#    'subsection': 6,
#    'series': 5,
#    'forma specialis': 5,
#    'epifamily': 4,
#    'natio': 4,
#    'morph': 4,
#    'subkingdom': 2,
#    'superclass': 2,
#    'subseries': 1,
#    'species aggregate': 1},
#   'namesByStatusCount': {'established': 527541,
#    'acceptable': 474029,
#    'unacceptable': 14899,
#    'not established': 11944,
#    'doubtful': 1654,
#    'manuscript': 1461,
#    'rejected': 342,
#    'conserved': 88},
#   'namesByTypeCount': {'scientific': 4410340, 'virus': 8046},
#   'nameRelationsByTypeCount': {'basionym': 278701,
#    'type': 32482,
#    'superfluous': 37,
#    'later homonym': 4,
#    'replacement name': 1},
#   'synonymsByRankCount': {'species': 1632955,
#    'variety': 163214,
#    'subspecies': 88617,
#    'form': 31956,
#    'infraspecific name': 28655,
#    'genus': 17258,
#    'unranked': 14578,
#    'subgenus': 1677,
#    'family': 1475,
#    'tribe': 1132,
#    'subfamily': 807,
#    'infrageneric name': 547,
#    'subvariety': 489,
#    'subtribe': 406,
#    'order': 328,
#    'infraorder': 263,
#    'section': 239,
#    'proles': 98,
#    'subform': 89,
#    'class': 58,
#    'suborder': 55,
#    'superfamily': 52,
#    'infratribe': 41,
#    'infrasubspecific name': 32,
#    'aberration': 28,
#    'phylum': 15,
#    'superorder': 13,
#    'subclass': 6,
#    'series': 5,
#    'forma specialis': 5,
#    'subsection': 4,
#    'morph': 4,
#    'kingdom': 1,
#    'nanorder': 1,
#    'supertribe': 1,
#    'subseries': 1,
#    'species aggregate': 1,
#    'natio': 1},
#   'taxaByRankCount': {'species': 2022580,
#    'genus': 197258,
#    'subspecies': 131415,
#    'variety': 27288,
#    'infraspecific name': 14247,
#    'family': 12919,
#    'subgenus': 12540,
#    'subfamily': 4964,
#    'tribe': 2794,
#    'order': 1585,
#    'superfamily': 1407,
#    'form': 1017,
#    'subtribe': 570,
#    'class': 392,
#    'suborder': 375,
#    'infraorder': 147,
#    'phylum': 118,
#    'subclass': 87,
#    'superorder': 34,
#    'subphylum': 31,
#    'parvorder': 29,
#    'unranked': 21,
#    'infraclass': 20,
#    'subvariety': 15,
#    'subterclass': 10,
#    'section': 10,
#    'infrageneric name': 10,
#    'nanorder': 9,
#    'kingdom': 8,
#    'supertribe': 5,
#    'epifamily': 4,
#    'natio': 3,
#    'subkingdom': 2,
#    'superclass': 2,
#    'subsection': 2},
#   'usagesByStatusCount': {'accepted': 2349763,
#    'synonym': 1880758,
#    'ambiguous synonym': 94683,
#    'provisionally accepted': 82155,
#    'misapplied': 9666},
#   'usagesByOriginCount': {'source': 4412925,
#    'implicit name': 3649,
#    'user': 451},
#   'vernacularsByLanguageCount': {'eng': 142148,
#    'cmn': 60319,
#    'spa': 24995,
#    'deu': 17327,
#    'fra': 16420,
#    'por': 16230,
#    'jpn': 13217,
#    'est': 10475,
#    'msa': 9504,
#    'rus': 8968,
#    'ita': 6069,
#    'dan': 5785,
#    'fin': 5534,
#    'ces': 5327,
#    'ara': 3948,
#    'ceb': 3810,
#    'tgl': 3796,
#    'tam': 3105,
#    'nld': 2951,
#    'mal': 2827,
#    'ell': 2663,
#    'afr': 2526,
#    'swe': 2298,
#    'pol': 2014,
#    'tur': 1730,
#    'kor': 1586,
#    'vie': 1566,
#    'bik': 1523,
#    'zho': 1493,
#    'tha': 1430,
#    'ilo': 1184,
#    'war': 1171,
#    'fij': 1110,
#    'mar': 1092,
#    'swa': 1019,
#    'tel': 1015,
#    'sqi': 1000,
#    'hrv': 960,
#    'cal': 954,
#    'daw': 944,
#    'smo': 923,
#    'hil': 883,
#    'ben': 878,
#    'mlt': 860,
#    'hin': 839,
#    'tah': 832,
#    'wol': 764,
#    'sin': 757,
#    'srp': 752,
#    'nor': 719,
#    'cat': 707,
#    'kan': 694,
#    'sgd': 658,
#    'khm': 642,
#    'rom': 605,
#    'jav': 589,
#    'div': 578,
#    'fas': 539,
#    'haw': 524,
#    'cbq': 511,
#    'pap': 508,
#    'mah': 497,
#    'iku': 485,
#    'pau': 482,
#    'cbk': 479,
#    'nlg': 443,
#    'nya': 417,
#    'guj': 416,
#    'nep': 412,
#    'rol': 409,
#    'som': 399,
#    'isl': 396,
#    'tbk': 384,
#    'mya': 355,
#    'dnj': 350,
#    'ind': 343,
#    'tkl': 340,
#    'fao': 330,
#    'cos': 314,
#    'hun': 304,
#    'heb': 301,
#    'mlg': 291,
#    'ewe': 288,
#    'agn': 276,
#    'keb': 274,
#    'slv': 255,
#    'kim': 254,
#    'cjk': 252,
#    'cym': 250,
#    'sco': 250,
#    'cgc': 228,
#    'hau': 223,
#    'pmt': 223,
#    'ace': 219,
#    'mri': 209,
#    'way': 191,
#    'pam': 189,
#    'ton': 188,
#    'ivv': 185,
#    'ukr': 183,
#    'pag': 181,
#    'lit': 161,
#    'yue': 160,
#    'fon': 158,
#    'srm': 155,
#    'mrv': 153,
#    'asm': 152,
#    'pan': 146,
#    'nob': 138,
#    'ray': 138,
#    'mon': 136,
#    'nno': 136,
#    'skg': 135,
#    'ori': 133,
#    'bul': 131,
#    'lav': 131,
#    'slk': 126,
#    'kdk': 125,
#    'bem': 124,
#    'rap': 118,
#    'grn': 114,
#    'srn': 114,
#    'yor': 112,
#    'mnk': 110,
#    'sus': 108,
#    'ron': 107,
#    'kri': 106,
#    'wls': 100,
#    'hai': 96,
#    'nup': 95,
#    'dip': 94,
#    'niu': 86,
#    'zne': 86,
#    'bcn': 85,
#    'cha': 85,
#    'loo': 84,
#    'aze': 81,
#    'guc': 81,
#    'kau': 81,
#    'fan': 78,
#    'hye': 75,
#    'fwa': 74,
#    'gle': 73,
#    'vif': 71,
#    'iba': 68,
#    'dyo': 65,
#    'kir': 65,
#    'ibo': 63,
#    'mos': 63,
#    'tvl': 61,
#    'fry': 55,
#    'tum': 53,
#    'snd': 50,
#    'kat': 49,
#    'kok': 47,
#    'urd': 47,
#    'mni': 46,
#    'tsi': 45,
#    'bis': 44,
#    'men': 44,
#    'bbc': 43,
#    'hei': 43,
#    'jaz': 43,
#    'koo': 43,
#    'luo': 43,
#    'uzb': 43,
#    'cre': 41,
#    'cgg': 40,
#    'kaz': 39,
#    'shk': 39,
#    'ada': 38,
#    'nus': 38,
#    'yao': 38,
#    'tuv': 37,
#    'smk': 35,
#    'snk': 34,
#    'lia': 33,
#    'kha': 31,
#    'ven': 31,
#    'ems': 30,
#    'seh': 30,
#    'bci': 29,
#    'glv': 28,
#    'kas': 28,
#    'piz': 27,
#    'amh': 26,
#    'nyo': 25,
#    'kal': 24,
#    'pkb': 24,
#    'bck': 23,
#    'elo': 23,
#    'nyh': 23,
#    'mkd': 22,
#    'goa': 21,
#    'gni': 20,
#    'ung': 19,
#    'wmt': 18,
#    'bvb': 17,
#    'adj': 16,
#    'bal': 16,
#    'tox': 16,
#    'bod': 15,
#    'gla': 15,
#    'thy': 15,
#    'alz': 14,
#    'bam': 14,
#    'glg': 14,
#    'ibg': 14,
#    'nyf': 14,
#    'rug': 14,
#    'scn': 14,
#    'dmm': 13,
#    'nem': 13,
#    'fub': 12,
#    'kom': 12,
#    'loz': 12,
#    'nuk': 12,
#    'fil': 11,
#    'plu': 11,
#    'que': 11,
#    'bta': 10,
#    'eus': 10,
#    'kos': 10,
#    'run': 10,
#    'chh': 9,
#    'epo': 9,
#    'txy': 9,
#    'aka': 8,
#    'chv': 8,
#    'kky': 8,
#    'miq': 8,
#    'swh': 8,
#    'lke': 7,
#    'lno': 7,
#    'rub': 7,
#    'sah': 7,
#    'bin': 6,
#    'mcn': 6,
#    'mug': 6,
#    'orm': 6,
#    'dig': 5,
#    'eee': 5,
#    'jbu': 5,
#    'lao': 5,
#    'mcs': 5,
#    'mua': 5,
#    'oka': 5,
#    'ona': 5,
#    'tui': 5,
#    'bre': 4,
#    'efi': 4,
#    'kik': 4,
#    'luy': 4,
#    'meu': 4,
#    'shs': 4,
#    'sun': 4,
#    'arw': 3,
#    'bua': 3,
#    'dua': 3,
#    'kbl': 3,
#    'khq': 3,
#    'kvf': 3,
#    'lin': 3,
#    'mer': 3,
#    'nie': 3,
#    'nzi': 3,
#    'pih': 3,
#    'ryu': 3,
#    'saq': 3,
#    'tfi': 3,
#    'tir': 3,
#    'twi': 3,
#    'ain': 2,
#    'bdm': 2,
#    'bib': 2,
#    'dzo': 2,
#    'enq': 2,
#    'foi': 2,
#    'int': 2,
#    'kam': 2,
#    'kwc': 2,
#    'lan': 2,
#    'lol': 2,
#    'lop': 2,
#    'lus': 2,
#    'mau': 2,
#    'mey': 2,
#    'mlf': 2,
#    'mlj': 2,
#    'mui': 2,
#    'nan': 2,
#    'oci': 2,
#    'res': 2,
#    'sbd': 2,
#    'sjm': 2,
#    'umb': 2,
#    'xho': 2,
#    'alq': 1,
#    'avi': 1,
#    'bnc': 1,
#    'bos': 1,
#    'bqp': 1,
#    'bsy': 1,
#    'bus': 1,
#    'bvf': 1,
#    'cnr': 1,
#    'dai': 1,
#    'dtp': 1,
#    'ebg': 1,
#    'esn': 1,
#    'etu': 1,
#    'gbp': 1,
#    'gdk': 1,
#    'hak': 1,
#    'hmo': 1,
#    'inn': 1,
#    'kcu': 1,
#    'ker': 1,
#    'kie': 1,
#    'kru': 1,
#    'ksp': 1,
#    'kxd': 1,
#    'kxh': 1,
#    'kzd': 1,
#    'kzr': 1,
#    'lij': 1,
#    'lil': 1,
#    'lue': 1,
#    'lug': 1,
#    'mqx': 1,
#    'ngc': 1,
#    'pny': 1,
#    'ruc': 1,
#    'sie': 1,
#    'skr': 1,
#    'swy': 1,
#    'tbw': 1,
#    'tdv': 1,
#    'thv': 1,
#    'tmh': 1,
#    'tpw': 1,
#    'tuk': 1,
#    'tuo': 1,
#    'xal': 1,
#    'zlm': 1,
#    'zsm': 1,
#    'zul': 1},
#   'origin': 'managed',
#   'verbatimCount': 0,
#   'usagesCount': 4417025,
#   'taxonConceptRelationsCount': 0,
#   'speciesInteractionsCount': 0,
#   'nameRelationsCount': 311225}]

# %% [markdown]
# * `/dataset/{dataset1}/diff/{diff2}` - can't get into this one (auth fail), but judging from the name, does it do an anti-union of two datasets? If this worked with most recent version of CoL checklist against an earlier version, that could be useful for clocking name changes.

# %% [markdown]
# #### Summary of other endpoints
#
# `/importer`: ops for managing/monitoring uploads. Has ome calls that seem to duplicate content from `/dataset`, so suspect this one is more for collaborators to manage their data.
#
# `/version`: does what it says on the tin - think it's the api version, rather than the data.
#
# `/admin`: Can't auth into these, for fairly obvious reasons. One or two or the GET ops look like summary counts/stats for the underlying data, which could be helpful for diffing
#
# `/export`: ops for managing/monitoring downloads
#
# `/image`: Not sure what this is - looks like it might be more for embedding maps/trees in external sites?
#
# `/name`: only service under here is name matching, same as the GBIF service I think.
#
# `/nameusage`: looks like it's for references to taxa names, though I can't tell if it's the 'this species was first described in...' nomenclatural prov-type info, or 'this checklist dataset is derived from this research paper...'
#
# `/ndix`: woman_shrugging_emoji
#
# `/openapi`: Overview of paths and components
#
# `/parser`: Taxonomic name parsing?
#
# `/user`: User info (GBIF auth) with last logged in timestamp etc - would be useful with some of the 'updatedBy' values in other resources.
#
# `/vernacular`: Returns vernacular names that match a string
#
# `/vocab`: Enums and term lists for vocabs.

# %% [markdown]
# ___________
# ### 3. NSIDR
# ____________
#
# [Github repo](https://github.com/DiSSCo/nsidr)
# [Web app](https://nsidr.org/)
#
# ... there doesn't seem to be anything here? There are refs to documentation on the app's landing page, but no links - unless that specifically refers to corda docs? Some calls are buildable by using the GUI + grabbing the URL.
